# %%
# !yes | add-apt-repository ppa:mscore-ubuntu/mscore3-stable
# !apt update
# !apt install musescore3
# !ln -s /usr/bin/musescore3 /usr/bin/musescore
# Out:
# Repository: 'deb https://ppa.launchpadcontent.net/mscore-ubuntu/mscore3-stable/ubuntu/ jammy main'
# Description:
# ~~~~~~~~~ MUSESCORE 3 RELEASES FOR UBUNTU 18.04 AND LATER ~~~~~~~~~
# Note that Canonical doesn’t allow new builds for releases marked obsolete
# (any nōn-LTS predating the previous LTS (currently 24.04 “noble”), and any LTS
# older than 7 years, currently anything before 14.04 “trusty”). The packages
# for those older releases here can no longer be updated but still work, within
# limitations. Best to upgrade to a supported release of the operating system!
#
# INSTALLING: (run these commands from the terminal)
#   sudo add-apt-repository ppa:mscore-ubuntu/mscore3-stable
#   sudo apt-get update
#   sudo apt-get install musescore3
#
# DO *NOT* USE THESE PPAs on Debian, only on Ubuntu!
#
# ‣‣‣ These packages are NOT suitable for ”KDE neon 18.04 (bionic)”!
# ‣ Use https://build.opensuse.org/project/show/home:mirabile:mscore instead.
# ...

# %%
# !pip install git+https://github.com/mathigatti/midi2voice.git
# Out:
# ...
#   Cloning https://github.com/mathigatti/midi2voice.git to /tmp/pip-req-build-e59qyb04
#   Running command git clone --filter=blob:none --quiet https://github.com/mathigatti/midi2voice.git /tmp/pip-req-build-e59qyb04
#   Resolved https://github.com/mathigatti/midi2voice.git to commit ebd5650dbbaff3b25058e14cbdcca0c08167e494
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.9 MB/s eta 0:00:00
# ...
#   Created wheel for midi2voice: filename=midi2voice-1.0.4-py3-none-any.whl size=7938 sha256=85e68d1eb40bdd1e25496846630c86f742629a82d7b92afe6b7d0cdc32ee2f43
#   Stored in directory: /tmp/pip-ephem-wheel-cache-obuyofoj/wheels/8e/f1/74/ffe7861de575283529e85a4a562dbbe9742c2e8ec487d4a79e
# Successfully built midi2voice
# ...

# %%
# Download file samples to test it
# !wget -O shallow.mid https://github.com/mathigatti/midi2voice/blob/master/inputs/shallow.mid?raw=true
# !wget -O shallow.txt https://raw.githubusercontent.com/mathigatti/midi2voice/master/inputs/shallow.txt
# Out:
# --2024-04-07 08:41:07--  https://github.com/mathigatti/midi2voice/blob/master/inputs/shallow.mid?raw=true
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/mathigatti/midi2voice/raw/master/inputs/shallow.mid [following]
# --2024-04-07 08:41:07--  https://github.com/mathigatti/midi2voice/raw/master/inputs/shallow.mid
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/mathigatti/midi2voice/master/inputs/shallow.mid [following]
# --2024-04-07 08:41:07--  https://raw.githubusercontent.com/mathigatti/midi2voice/master/inputs/shallow.mid
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %% [markdown]
# ### Example using command line

# %%
# %%time
# It might take a little bit
# !python -m midi2voice -l lyrics.txt -m output.mid -g female -t 96
# Out:
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'
# convert <output.mid>...
# 	to <temp.xml>
# ... success!
# CPU times: user 72.4 ms, sys: 11 ms, total: 83.4 ms
# Wall time: 10 s

# %%
import IPython.display as ipd
ipd.Audio("voice.wav")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Example using python code

# %%
from midi2voice import renderize_voice

with open("lyrics.txt", 'r') as text:
	lyrics = text.readlines()

# Detail of all the default params: renderize_voice(lyrics, "shallow.mid", tempo=80, lang="english", gender="female", voiceindex=0, out_folder=".", vibpower=1, f0shift=0, synalpha=0.55)
renderize_voice(lyrics, "output.mid", tempo=96, lang="english", gender="female",voiceindex=1)

# %%
import IPython.display as ipd
ipd.Audio("voice.wav")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !pip install music21

# %%
from music21 import converter
midi_stream = converter.parse("output.mid")
# Convert and write as MusicXML
midi_stream.write('xml', "temp.xml")
# Out:
# PosixPath('/content/temp.xml')
